# %%
from data_prep import generate_labels

# %%
df_train = generate_labels()
df_train.head()
# Out:
#    unit_number  time_in_cycles  op_setting_1  op_setting_2  op_setting_3  \
# 0            1               1       -0.0007       -0.0004         100.0
# 1            1               2        0.0019       -0.0003         100.0
# 2            1               3       -0.0043        0.0003         100.0
# 3            1               4        0.0007        0.0000         100.0
# 4            1               5       -0.0019       -0.0002         100.0
#
#    sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_14  \
# 0    518.67    641.82   1589.70   1400.60     14.62  ...    8138.62
# 1    518.67    642.15   1591.82   1403.14     14.62  ...    8131.49
# 2    518.67    642.35   1587.99   1404.20     14.62  ...    8133.23
# 3    518.67    642.35   1582.79   1401.87     14.62  ...    8133.83
# 4    518.67    642.37   1582.85   1406.22     14.62  ...    8133.80
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# ...

# %%
df_test = generate_labels('FD001','test')
df_test.head()
# Out:
#    unit_number  time_in_cycles  op_setting_1  op_setting_2  op_setting_3  \
# 0            1               1        0.0023        0.0003         100.0
# 1            1               2       -0.0027       -0.0003         100.0
# 2            1               3        0.0003        0.0001         100.0
# 3            1               4        0.0042        0.0000         100.0
# 4            1               5        0.0014        0.0000         100.0
#
#    sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_14  \
# 0    518.67    643.02   1585.29   1398.21     14.62  ...    8125.55
# 1    518.67    641.71   1588.45   1395.42     14.62  ...    8139.62
# 2    518.67    642.46   1586.94   1401.34     14.62  ...    8130.10
# 3    518.67    642.44   1584.12   1406.42     14.62  ...    8132.90
# 4    518.67    642.51   1587.19   1401.92     14.62  ...    8129.54
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# ...

# %%
df_test.tail()
# Out:
#        unit_number  time_in_cycles  op_setting_1  op_setting_2  op_setting_3  \
# 13091          100             194        0.0049        0.0000         100.0
# 13092          100             195       -0.0011       -0.0001         100.0
# 13093          100             196       -0.0006       -0.0003         100.0
# 13094          100             197       -0.0038        0.0001         100.0
# 13095          100             198        0.0013        0.0003         100.0
#
#        sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_14  \
# 13091    518.67    643.24   1599.45   1415.79     14.62  ...    8213.28
# 13092    518.67    643.22   1595.69   1422.05     14.62  ...    8210.85
# 13093    518.67    643.44   1593.15   1406.82     14.62  ...    8217.24
# 13094    518.67    643.26   1594.99   1419.36     14.62  ...    8220.48
# 13095    518.67    642.95   1601.62   1424.99     14.62  ...    8214.64
#
# ...
